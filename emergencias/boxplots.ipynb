# %%
import statistics
import numpy as np
import seaborn as sns
from scipy import stats
from statistics import mean
import matplotlib.pyplot as plt

# %%
# %store -r emer_mlp_day
# %store -r emer_mlp_day_priority
# %store -r emer_mlp_day_region
# %store -r emer_mlp_day_type
# %store -r emer_lstm_day
# %store -r emer_lstm_day_priority
# %store -r emer_lstm_day_region
# %store -r emer_lstm_day_type
# %store -r emer_lstm_day_region_single
# %store -r emer_lstm_day_region_mul
# %store -r emer_lstm_hour
# %store -r emer_mlp_hour

# %%
sns.set_style("darkgrid")
cm = 1/2.54 
colors = ['#4477AA', '#EE6677', '#228833', '#CCBB44', '#66CCEE', '#AA3377', '#BBBBBB']
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

# %% [markdown]
# ### LSTM

# %%
q = np.quantile(emer_lstm_day[2], [0,0.25,0.5,0.75,1])
q1, q2, q3 = q[1], q[2], q[3]

# %%
mae, rmse, smape = emer_lstm_day[0], emer_lstm_day[1], emer_lstm_day[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_lstm_daily_boxplot.pdf')

# %%
mae, rmse, smape = emer_lstm_day_region[0], emer_lstm_day_region[1], emer_lstm_day_region[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_lstm_daily_region_boxplot.pdf')

# %%
mae, rmse, smape = emer_lstm_day_priority[0], emer_lstm_day_priority[1], emer_lstm_day_priority[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_lstm_daily_priority_boxplot.pdf')

# %%
mae, rmse, smape = emer_lstm_day_type[0], emer_lstm_day_type[1], emer_lstm_day_type[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_lstm_daily_type_boxplot.pdf')

# %%
mae, rmse, smape = emer_lstm_day_region_single[0], emer_lstm_day_region_single[1], emer_lstm_day_region_single[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 100))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 100))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_lstm_daily_region_single_boxplot.pdf')

# %%
mae, rmse, smape = emer_lstm_day_region_mul[0], emer_lstm_day_region_mul[1], emer_lstm_day_region_mul[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 100))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 100))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_lstm_daily_region_mul_boxplot.pdf')

# %%
mae, rmse, smape = emer_lstm_hour[0], emer_lstm_hour[1], emer_lstm_hour[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 50))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 50))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 20))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_lstm_hour_boxplot.pdf')

# %% [markdown]
# ### MLP

# %%
q = np.quantile(emer_mlp_day[2], [0,0.25,0.5,0.75,1])
q1, q2, q3 = q[1], q[2], q[3]

# %%
mae, rmse, smape = emer_mlp_day[0], emer_mlp_day[1], emer_mlp_day[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_mlp_daily_boxplot.pdf')

# %%
mae, rmse, smape = emer_mlp_day_region[0], emer_mlp_day_region[1], emer_mlp_day_region[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_mlp_daily_region_boxplot.pdf')

# %%
mae, rmse, smape = emer_mlp_day_priority[0], emer_mlp_day_priority[1], emer_mlp_day_priority[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_mlp_daily_priority_boxplot.pdf')

# %%
mae, rmse, smape = emer_mlp_day_type[0], emer_mlp_day_type[1], emer_mlp_day_type[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 500))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 500))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_mlp_daily_type_boxplot.pdf')

# %%
mae, rmse, smape = emer_mlp_hour[0], emer_mlp_hour[1], emer_mlp_hour[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 50))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 50))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 20))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/emergencies_mlp_hour_boxplot.pdf')
