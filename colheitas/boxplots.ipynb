# %%
import statistics
import numpy as np
import seaborn as sns
from scipy import stats
from statistics import mean
import matplotlib.pyplot as plt

# %%
# %store -r supply_mlp_month
# %store -r supply_mlp_month_abo
# %store -r supply_mlp_month_cst
# %store -r supply_mlp_month_rh
# %store -r supply_mlp_month_sex
# %store -r supply_mlp_week
# %store -r supply_lstm_month
# %store -r supply_lstm_month_abo
# %store -r supply_lstm_month_cst
# %store -r supply_lstm_month_rh
# %store -r supply_lstm_month_sex
# %store -r supply_lstm_month_cst_multi
# %store -r supply_lstm_month_cst_single
# %store -r supply_lstm_week
# %store -r supply_lstm_week_cst

# %%
sns.set_style("darkgrid")
cm = 1/2.54 
colors = ['#4477AA', '#EE6677', '#228833', '#CCBB44', '#66CCEE', '#AA3377', '#BBBBBB']
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

# %% [markdown]
# ### LSTM

# %%
q = np.quantile(supply_lstm_month[2], [0,0.25,0.5,0.75,1])
q1, q2, q3 = q[1], q[2], q[3]

# %%
mae, rmse, smape = supply_lstm_month[0], supply_lstm_month[1], supply_lstm_month[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_month_abo[0], supply_lstm_month_abo[1], supply_lstm_month_abo[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_abo_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_month_cst[0], supply_lstm_month_cst[1], supply_lstm_month_cst[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_cst_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_month_rh[0], supply_lstm_month_rh[1], supply_lstm_month_rh[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_rh_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_month_sex[0], supply_lstm_month_sex[1], supply_lstm_month_sex[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_sex_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_month_cst_multi[0], supply_lstm_month_cst_multi[1], supply_lstm_month_cst_multi[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 1000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 1000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 15))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_cst_multi_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_month_cst_single[0], supply_lstm_month_cst_single[1], supply_lstm_month_cst_single[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 1000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 1000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 15))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_cst_single_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_week[0], supply_lstm_week[1], supply_lstm_week[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 1000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 1000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 20))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_weekly_boxplot.pdf')

# %%
mae, rmse, smape = supply_lstm_week_cst[0], supply_lstm_week_cst[1], supply_lstm_week_cst[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 1000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 1000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 20))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_lstm_weekly_cst_boxplot.pdf')

# %% [markdown]
# ### MLP

# %%
q = np.quantile(supply_mlp_month[2], [0,0.25,0.5,0.75,1])
q1, q2, q3 = q[1], q[2], q[3]

# %%
mae, rmse, smape = supply_mlp_month[0], supply_mlp_month[1], supply_mlp_month[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_mlp_monthly_boxplot.pdf')

# %%
mae, rmse, smape = supply_mlp_month_abo[0], supply_mlp_month_abo[1], supply_mlp_month_abo[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_mlp_monthly_abo_boxplot.pdf')

# %%
mae, rmse, smape = supply_mlp_month_cst[0], supply_mlp_month_cst[1], supply_mlp_month_cst[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_mlp_monthly_cst_boxplot.pdf')

# %%
mae, rmse, smape = supply_mlp_month_rh[0], supply_mlp_month_rh[1], supply_mlp_month_rh[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_mlp_monthly_rh_boxplot.pdf')

# %%
mae, rmse, smape = supply_mlp_month_sex[0], supply_mlp_month_sex[1], supply_mlp_month_sex[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_mlp_monthly_sex_boxplot.pdf')

# %%
mae, rmse, smape = supply_mlp_week[0], supply_mlp_week[1], supply_mlp_week[2]
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 1000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 1000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 20))
axes[2].axhline(q1, color='r', dashes=(2,2), linewidth=1)
axes[2].axhline(q2, color='r', linewidth=1)
axes[2].axhline(q3, color='r', dashes=(2,2), linewidth=1)
plt.tight_layout()
plt.savefig('figures/supply_mlp_weekly_boxplot.pdf')
