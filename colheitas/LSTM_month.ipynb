# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
from numpy import array
from datetime import datetime
import seaborn as sns
# Out:
# 2022-10-20 04:05:22.181438: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-10-20 04:05:22.181490: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
sns.set_style("darkgrid")
cm = 1/2.54 
colors = ['#4477AA', '#EE6677', '#228833', '#CCBB44', '#66CCEE', '#AA3377', '#BBBBBB']
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "sans-serif",
    "font.sans-serif": ["Helvetica"]})

# %% [markdown]
# ### Replace missing values with Zero and Group by month

# %%
df= pd.read_csv('colheitas.csv', parse_dates=['date'])
df['nr'].fillna(value=0, inplace=True)
df=df.groupby('date').sum()
df=df.resample(rule='M').sum()
df = df.iloc[:-1 , :]
dataset = df.values
dataset = df.astype('float32')
df.plot(figsize=(17*cm,12*cm), legend=None)
plt.ylabel('Monthly Supply')
plt.xlabel('Date')
plt.savefig('figures/supply_monthly.pdf')

# %% [markdown]
# ### Create batches of training data (12 months)

# %%
def split_sequence(sequence, n_steps_in, n_steps_out, slide):
    X, y = list(), list()
    for i in range(0, len(sequence), slide):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the sequence
        if out_end_ix > len(sequence):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %% [markdown]
# ### Define and fit LSTM model

# %%
def fit(X, y, n_steps_in, n_steps_out):
    callback = EarlyStopping(monitor='loss', patience=50)
    model = Sequential()
    model.add(LSTM(units=70, activation='relu', input_shape=(n_steps_in, 1)))
    model.add(Dense(n_steps_out))
    model.compile(optimizer='adam', loss='mse')
    model.fit(X, y, epochs=500, callbacks=[callback])
    return model

# %%
def train_predict(dataset, test, actual):
    n_steps_in, n_steps_out, slide = 6, 2, 1
    X, y = split_sequence(dataset, n_steps_in, n_steps_out, slide)
    
    model = fit(X, y, n_steps_in, n_steps_out)
    
    mae, rmse, smape = list(), list(), list()
    for i in range(0, len(test)-n_steps_in, n_steps_out):
        x_input = array(test[i:n_steps_in+i])
        x_input = x_input.reshape((1, n_steps_in, 1))
        pred = model.predict(x_input).reshape(-1, 1)
        pred = scaler.inverse_transform(pred)
        mae_aux, rmse_aux, smape_aux = measure_error(actual, pred, n_steps_in, n_steps_out, i)
        mae.append(mae_aux), rmse.append(rmse_aux), smape.append(smape_aux)
    
    return mae, rmse, smape

# %%
def sMAPE(actual, predicted):
    if not all([isinstance(actual, np.ndarray), 
                isinstance(predicted, np.ndarray)]):
        actual, predicted = np.array(actual),
        np.array(predicted)
    return round(np.mean(np.abs(predicted - actual) / ((np.abs(predicted) + np.abs(actual))/2))*100, 2)

# %%
def measure_error(actual, pred, step_in, step_out, index):
    #print(actual[index+step_in:index+step_in+step_out],pred,index+step_in,index+step_in+step_out)
    mae = mean_absolute_error(actual[index+step_in:index+step_in+step_out], pred)
    rmse = np.sqrt(mean_squared_error(actual[index+step_in:index+step_in+step_out], pred))
    smape = sMAPE(actual[index+step_in:index+step_in+step_out], pred)
    return mae, rmse, smape

# %% [markdown]
# ### Normalize Data Set and Split Train and Test

# %%
len(df)
# Out:
# 251

# %%
dataset = df.values
dataset = df.astype('float32')
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
train=dataset[:215] 
test=dataset[215:]  
mae, rmse, smape = train_predict(train, test, df[215:].values)
# Out:
# 2022-10-06 02:32:05.421868: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-10-06 02:32:05.421913: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-10-06 02:32:05.421956: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ubuntu): /proc/driver/nvidia/version does not exist
# 2022-10-06 02:32:05.422377: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/500
# 7/7 [==============================] - 2s 5ms/step - loss: 0.3616
# Epoch 2/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2777
# Epoch 3/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1948
# Epoch 4/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1128
# Epoch 5/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0392
# Epoch 6/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0175
# Epoch 7/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0188
# Epoch 8/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0128
# Epoch 9/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0134
# Epoch 10/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0113
# Epoch 11/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0113
# Epoch 12/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0107
# Epoch 13/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0106
# Epoch 14/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 15/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0101
# Epoch 16/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0098
# Epoch 17/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0096
# Epoch 18/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 19/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 20/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0096
# Epoch 21/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 22/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0096
# Epoch 23/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0093
# Epoch 24/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0093
# Epoch 25/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0092
# Epoch 26/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 27/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 28/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 29/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0091
# Epoch 30/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 31/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0094
# Epoch 32/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0094
# Epoch 33/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0091
# Epoch 34/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 35/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0092
# Epoch 36/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0090
# Epoch 37/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0090
# Epoch 38/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 39/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0089
# Epoch 40/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 41/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0089
# Epoch 42/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0091
# Epoch 43/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0088
# Epoch 44/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0089
# Epoch 45/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0089
# Epoch 46/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0088
# Epoch 47/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0088
# Epoch 48/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0089
# Epoch 49/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0087
# Epoch 50/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0088
# Epoch 51/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0088
# Epoch 52/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0087
# Epoch 53/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0087
# Epoch 54/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 55/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 56/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 57/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 58/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0087
# Epoch 59/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 60/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 61/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0085
# Epoch 62/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0085
# Epoch 63/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0085
# Epoch 64/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0084
# Epoch 65/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0085
# Epoch 66/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0083
# Epoch 67/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0083
# Epoch 68/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0083
# Epoch 69/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0082
# Epoch 70/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082
# Epoch 71/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0081
# Epoch 72/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 73/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 74/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0082
# Epoch 75/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0082
# Epoch 76/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 77/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0082
# Epoch 78/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0082
# Epoch 79/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0080
# Epoch 80/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0082
# Epoch 81/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0081
# Epoch 82/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0081
# Epoch 83/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 84/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 85/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 86/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0077
# Epoch 87/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 88/500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0077
# Epoch 89/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0078
# Epoch 90/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0079
# Epoch 91/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0077
# Epoch 92/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0078
# Epoch 93/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0076
# Epoch 94/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 95/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0076
# Epoch 96/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 97/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0075
# Epoch 98/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 99/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0075
# Epoch 100/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0075
# Epoch 101/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0074
# Epoch 102/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 103/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 104/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0076
# Epoch 105/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0076
# Epoch 106/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0074
# Epoch 107/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0072
# Epoch 108/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0073
# Epoch 109/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0073
# Epoch 110/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0072
# Epoch 111/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 112/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 113/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0077
# Epoch 114/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0077
# Epoch 115/500
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0075
# Epoch 116/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0078
# Epoch 117/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 118/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0073
# Epoch 119/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0074
# Epoch 120/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0074
# Epoch 121/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 122/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 123/500
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 124/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0074
# Epoch 125/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0073
# Epoch 126/500
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0071
# Epoch 127/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0071
# Epoch 128/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 129/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 130/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0071
# Epoch 131/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 132/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 133/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0071
# Epoch 134/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0071
# Epoch 135/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 136/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 137/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0070
# Epoch 138/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0070
# Epoch 139/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 140/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 141/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 142/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 143/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0069
# Epoch 144/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 145/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 146/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 147/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 148/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 149/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 150/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 151/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 152/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 153/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 154/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0071
# Epoch 155/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0069
# Epoch 156/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0070
# Epoch 157/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0075
# Epoch 158/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0079
# Epoch 159/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0076
# Epoch 160/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0070
# Epoch 161/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0070
# Epoch 162/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0069
# Epoch 163/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 164/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 165/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 166/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 167/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 168/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 169/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 170/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 171/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 172/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 173/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 174/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 175/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 176/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 177/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 178/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0069
# Epoch 179/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 180/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0074
# Epoch 181/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 182/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 183/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 184/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 185/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 186/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 187/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 188/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 189/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 190/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 191/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 192/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 193/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 194/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 195/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 196/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 197/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 198/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 199/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 200/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 201/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 202/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 203/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 204/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 205/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 206/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 207/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 208/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 209/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 210/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 211/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 212/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 213/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0069
# Epoch 214/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 215/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 216/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 217/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 218/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 219/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 220/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 221/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 222/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 223/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 224/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 225/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 226/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 227/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 228/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 229/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 230/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 231/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 232/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 233/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 234/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 235/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 236/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 237/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 238/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 239/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 240/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 241/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0064
# Epoch 242/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0068
# Epoch 243/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 244/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 245/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 246/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 247/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 248/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 249/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 250/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 251/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0069
# Epoch 252/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 253/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 254/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 255/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 256/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 257/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 258/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 259/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 260/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 261/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 262/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 263/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0070
# Epoch 264/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 265/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 266/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 267/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 268/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 269/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 270/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 271/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 272/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 273/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 274/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 275/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 276/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 277/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 278/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 279/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 280/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0065
# Epoch 281/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0064
# Epoch 282/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 283/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 284/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 285/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0067
# Epoch 286/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 287/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 288/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0066
# Epoch 289/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0064
# Epoch 290/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0068
# Epoch 291/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0070

# %%
len(smape)
# Out:
# 15

# %% [markdown]
# ### Calculate Error

# %%
fig, axes = plt.subplots(1, 3, sharex=True, figsize=(17*cm,12*cm))
sns.boxplot(ax=axes[0], y=mae, color='thistle', showfliers=False)
axes[0].set_title('MAE')
axes[0].set(ylim=(0, 2000))
sns.boxplot(ax=axes[1], y=rmse, color='lightsteelblue', showfliers=False)
axes[1].set_title('RMSE')
axes[1].set(ylim=(0, 2000))
sns.boxplot(ax=axes[2], y=smape, color='darkseagreen', showfliers=False)
axes[2].set_title('sMAPE (\%)')
axes[2].set(ylim=(0, 10))
plt.tight_layout()
plt.savefig('figures/supply_lstm_monthly_boxplot.pdf')

# %%
supply_lstm_month = [mae,rmse,smape]
# %store supply_lstm_month
# Out:
# Stored 'supply_lstm_month' (list)
